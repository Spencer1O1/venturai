# %%
# !pip install google-cloud-storage google-cloud-bigquery xgboost db-dtypes
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: google-cloud-storage in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (2.14.0)
# Requirement already satisfied: google-cloud-bigquery in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (3.17.2)
# Requirement already satisfied: xgboost in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: db-dtypes in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-cloud-storage) (1.5.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /databricks/python3/lib/python3.10/site-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-cloud-storage) (2.7.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.23.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-cloud-storage) (2.28.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-cloud-storage) (2.17.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /databricks/python3/lib/python3.10/site-packages (from google-cloud-bigquery) (2.8.2)
# Requirement already satisfied: packaging>=20.0.0 in /databricks/python3/lib/python3.10/site-packages (from google-cloud-bigquery) (23.2)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.10/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.10/site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /databricks/python3/lib/python3.10/site-packages (from db-dtypes) (1.5.3)
# Requirement already satisfied: pyarrow>=3.0.0 in /databricks/python3/lib/python3.10/site-packages (from db-dtypes) (8.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /databricks/python3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /databricks/python3/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage) (4.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from google-auth<3.0dev,>=2.23.3->google-cloud-storage) (4.9)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas>=0.24.2->db-dtypes) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ef128308-b56c-4aee-9e54-9ad536dc9b65/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.23.3->google-cloud-storage) (0.5.1)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %% [markdown]
# ### Execute ML models

# %%
### By using target variable as variable 'Capacity'
from heater_health_data import classification_and_regression_ml_models

data = 'heater_train_test_data.csv'
var = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Current_charge', 'Voltage_charge', 'Time']
target_var = 'Heater_Health'  #'Capacity','Heater_Health'
model_type = 'classification'   #regression, classification
    
model_name='DTC'    #RFC,GBC,ADBC,DTC,SVC,NBC,XGBC,KNNC        - for classification model_types
# model_name='XGBR'    #RFR,GBR,ADBR,DTR,SVR,XGBR,LR,LGR,RIDGE    - for regression model_types

### RFC - Random Forest Classifier
# param_list = {'criterion': 'entropy',
#               'max_depth':None,
#               'min_samples_leaf': 2,
#               'min_samples_split': 2,
#               'n_estimators': 50}

### RFR - Random Forest Regressor
# param_list = {'criterion': 'squared_error',
#               'max_depth':15,
#               'min_samples_leaf': 2,
#               'min_samples_split': 2,
#               'n_estimators': 50}

### DTC - DecisionTree Classifier
param_list = {'criterion': 'entropy',
 'max_depth': 3,
 'min_samples_leaf': 1,
 'min_samples_split': 2,
 'splitter': 'best'}

### DTR - DecisionTree Regressor
# param_list = {'criterion': 'squared_error',
#  'max_depth': None,
#  'min_samples_leaf':8,
#  'min_samples_split': 2,
#  'splitter': 'best'}

### XGBC - Xgboost Classifier
# param_list = {'n_estimators':50,
#               'learning_rate':0.1,
#                'max_depth':9,
#               'min_child_weight':4,
#               'subsample':0.9,
#               'reg_lambda':5,
#               'reg_alpha':2}   

### XGBR - Xgboost Regressor
# param_list = {'booster':'gbtree', 
#               'n_estimators':4500,
#               'learning_rate':0.3147,
#                'max_depth':2,
#               'min_child_weight':4,
#               'subsample':1,
#               'reg_lambda':4,
#               'reg_alpha':1} 

### LR - Linear Regressor/LGR - Logistic regression/ RIDGE - RIDGE regression
# param_list = {'fit_intercept' : False,        # To calculate the intercept for this model.
#               'copy_X' : True}               # If True, X matrix copied before fitting the model and fitting process will
                                               # not affect the original data outside of the model.

### ADBC - AdaBoost Classifier
# param_list = {'n_estimators': 100,   
#               'learning_rate': 0.03}

### ADBR - AdaBoost Regressor
# param_list = {'loss': 'linear',
#               'n_estimators': 110,   
#               'learning_rate': 0.03}

### GBC - Gradient Boosting Classifier
# param_list = {'n_estimators': 40,               # Number of weak learners (trees) in the ensemble
#              'learning_rate': 0.2,              # Learning rate shrinks the contribution of each weak learner
#              'max_depth': 8,
#              'loss': 'log_loss',  #exponential
#              'min_samples_split': 2,
#              'min_samples_leaf':1}

### GBR - Gradient Boosting Regressor
# param_list = {'n_estimators': 36,               # Number of weak learners (trees) in the ensemble
#              'learning_rate': 0.2,              # Learning rate shrinks the contribution of each weak learner
#              'max_depth': 8,
#              'loss': 'squared_error', 
#              'min_samples_split': 2,
#              'min_samples_leaf':1}

### SVC - Support vector classifier
# param_list = {'kernel': 'linear'}                   #{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’}

### KNNC -
# param_list = {'n_neighbors' : 5,                # Number of neighbors to use by default for kneighbors queries.
#                'weights' : 'distance',           # {‘uniform’, ‘distance’}
#                'algorithm' : 'auto',            # {‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’} 
#                'p' : 2}                         # p = 1 : manhattan_distance (l1) and for p = 2 : euclidean_distance (l2) 

## Model pkl file
pickle_obj = False

a=classification_and_regression_ml_models(data, var, target_var, model_type, model_name, param_list, pickle_obj)
a
# DTC - Heater_Health
# XGBR - {'r2_score': 0.79319794297867, 'mean_absolute_error': 0.049185513658535567, 'mean_squared_error': 0.003939918274065363}
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     24984
#            1       1.00      1.00      1.00     25946
#
#     accuracy                           1.00     50930
#    macro avg       1.00      1.00      1.00     50930
# weighted avg       1.00      1.00      1.00     50930
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="57b5dc20-e90e-4bbc-8760-9a20e837f22f" class="plotly-graph-div" style="height:300px; width:300px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57b5dc20-e90e-4bbc-8760-9a20e837f22f")) {                    Plotly.newPlot(                        "57b5dc20-e90e-4bbc-8760-9a20e837f22f",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":false,"x":[0,1],"y":[0,1],"z":[[24984,0],[2,25944]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#000000"},"showarrow":false,"text":"24984","x":0,"xref":"x","y":0,"yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":1,"xref":"x","y":0,"yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"2","x":0,"xref":"x","y":1,"yref":"y"},{"font":{"color":"#000000"},"showarrow":false,"text":"25944","x":1,"xref":"x","y":1,"yref":"y"}],"xaxis":{"dtick":1,"gridcolor":"rgb(0, 0, 0)","side":"top","ticks":"","title":{"text":"Predicted"}},"yaxis":{"dtick":1,"ticks":"","ticksuffix":"  ","title":{"text":"True"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"out ...
#         test  pred  difference
# 118836   1.0   1.0         0.0
# 118837   1.0   1.0         0.0
# 118838   1.0   1.0         0.0
# 118839   1.0   1.0         0.0
# 118840   1.0   1.0         0.0
# ...      ...   ...         ...
# 169762   1.0   1.0         0.0
# 169763   1.0   1.0         0.0
# 169764   1.0   1.0         0.0
# 169765   1.0   1.0         0.0
# Total    NaN   NaN         2.0
#
# [50931 rows x 3 columns]

# %%
# import model_evaluation from heater_health_data.py
from heater_health_data import model_evaluation

data = 'heater_validation_data.csv'
var = ['Voltage_measured', 'Current_measured', 'Temperature_measured', 'Current_charge', 'Voltage_charge', 'Time']
model_name = 'XGBR'                     #'XGBR','DTC'

a=model_evaluation(data, var, model_name)
a
# Out:
#           pred
# 0     1.593891
# 1     1.368614
# 2     1.520856
# 3     1.834481
# 4     1.950890
# ...        ...
# 4995  1.758749
# 4996  1.662326
# 4997  1.569008
# 4998  1.205930
# 4999  1.653206
#
# [5000 rows x 1 columns]
